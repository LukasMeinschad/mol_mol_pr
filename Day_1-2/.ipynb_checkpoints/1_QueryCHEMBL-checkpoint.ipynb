# %% [markdown]
# # Compound Data Acquisition

# %% [markdown]
# Welcome to the practical course Molecular Modelling!
#
# This course will focus on computational methods for modeling of molecules, and is based on your already gained expertise from the lectures. You will try different methods and data visualization techniques throughout this course, followed by final presentation at the end. As this course is a practical course, you will need extra research about your target, the methods you used ...
#
# If something is unclear, feel free to ask our tutor(s)!
#
# In this notebook, we will learn more about the ChEMBL database and how to extract data from ChEMBL, i.e. (compound, activity data) pairs for a target of interest. These data sets can be used for many cheminformatics tasks, such as similarity search, clustering or machine learning.
#
# Our work here will include finding compounds which were tested against a target and filtering available bioactivity data.
#
# Goal: Get a list of compounds with bioactivity data for your target

# %% [markdown]
# ## ChEMBL database

# %% [markdown]
# ChEMBL is a manually curated database of bioactive molecules with drug-like properties. It brings together chemical, bioactivity and genomic data to aid the translation of genomic information into effective new drugs. See https://www.ebi.ac.uk/chembl/ for more information.
#
# Current data content (as of 12.2024, ChEMBL 35):
#
# >2.4 million distinct compounds
#
# >20.7 million activity values
#
# >Assays are mapped to ~16,000 targets

# %% [markdown]
# **Data sources** include scientific literature, PubChem bioassays, Drugs for Neglected Diseases Initiative (DNDi), BindingDB database, …
#
# ChEMBL data can be accessed via a web-interface [https://www.ebi.ac.uk/chembl/] (RESTful web service), the EBI-RDF platform [https://www.ncbi.nlm.nih.gov/pubmed/24413672] and the ChEMBL web rescource client [https://github.com/chembl/chembl_webresource_client] (Python client library for accessing ChEMBL data; handles interaction with the HTTPS protocol).

# %% [markdown]
# ## Compound activity measures

# %% [markdown]
# How is the potency of a drug usually measured?
#
# Check the following literature and answer the questions:
#
#
# Literature:
# 1) https://en.wikipedia.org/wiki/IC50
# 2) https://pubs.acs.org/doi/10.1021/acs.jmedchem.4c02052
# 3) https://pmc.ncbi.nlm.nih.gov/articles/PMC7357848/
# 4) https://pubmed.ncbi.nlm.nih.gov/32407356/
#
# Questions:
# 1) What does IC₅₀ represent in pharmacology?
# 2) How is IC₅₀ typically determined in an experiment?
# 3) Why the potency of a drug is usually measured by IC₅₀?"
# 4) What are the pros/cons of IC₅₀ as a potency metric?
# 5) What binding strength would you expect for a strong-binding drug?

# %% [markdown]
# ## Excercise 1

# %% [markdown]
# As you might already know from the Hands-On session (part of lectures), we need certain packages and python libraries to run specific code.

# %% [markdown]
# Let's import packages we're going to use further:

# %%
# %pip install chembl-webresource-client tqdm rdkit mols2grid
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: chembl-webresource-client in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (0.10.8)
# Requirement already satisfied: tqdm in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (4.64.1)
# Requirement already satisfied: rdkit in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (2022.9.5)
# Collecting mols2grid
#   Downloading mols2grid-2.0.0-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.18.4 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from chembl-webresource-client) (2.28.1)
# Requirement already satisfied: easydict in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from chembl-webresource-client) (1.10)
# Requirement already satisfied: urllib3 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from chembl-webresource-client) (1.26.14)
# Requirement already satisfied: requests-cache~=0.7.0 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from chembl-webresource-client) (0.7.5)
# Requirement already satisfied: numpy in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from rdkit) (1.22.3)
# Requirement already satisfied: Pillow in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from rdkit) (9.5.0)
# Requirement already satisfied: pandas in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from mols2grid) (2.0.0)
# Requirement already satisfied: jinja2>=2.11.0 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from mols2grid) (3.1.2)
# Collecting ipywidgets<8,>=7
#   Downloading ipywidgets-7.8.5-py2.py3-none-any.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.1/124.1 kB 9.5 MB/s eta 0:00:00
# Collecting widgetsnbextension~=3.6.10
#   Downloading widgetsnbextension-3.6.10-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.9 MB/s eta 0:00:00m eta 0:00:01
# Collecting jupyterlab-widgets<3,>=1.0.0
#   Downloading jupyterlab_widgets-1.1.11-py3-none-any.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.9/246.9 kB 36.2 MB/s eta 0:00:00
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from ipywidgets<8,>=7->mols2grid) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from ipywidgets<8,>=7->mols2grid) (8.12.0)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from ipywidgets<8,>=7->mols2grid) (0.1.3)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from ipywidgets<8,>=7->mols2grid) (5.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from jinja2>=2.11.0->mols2grid) (2.1.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from requests>=2.18.4->chembl-webresource-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from requests>=2.18.4->chembl-webresource-client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from requests>=2.18.4->chembl-webresource-client) (2022.12.7)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from requests-cache~=0.7.0->chembl-webresource-client) (1.4.3)
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from requests-cache~=0.7.0->chembl-webresource-client) (2.1.2)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from requests-cache~=0.7.0->chembl-webresource-client) (6.0)
# Collecting attrs<22.0,>=21.2
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from pandas->mols2grid) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from pandas->mols2grid) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from pandas->mols2grid) (2023.3)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (3.0.38)
# Requirement already satisfied: pickleshare in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.1.6)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (2.15.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.18.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (4.8.0)
# Requirement already satisfied: stack-data in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.6.2)
# Requirement already satisfied: six>=1.5 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->mols2grid) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (6.5.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (0.17.1)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (1.8.0)
# Requirement already satisfied: argon2-cffi in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (7.3.1)
# Requirement already satisfied: prometheus-client in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (0.16.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (8.2.0)
# Requirement already satisfied: tornado>=6.1 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (6.3)
# Requirement already satisfied: pyzmq>=17 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (25.0.2)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (0.5.5)
# Requirement already satisfied: ipykernel in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (6.22.0)
# Requirement already satisfied: nbformat in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (5.8.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (5.3.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.2.6)
# Requirement already satisfied: pure-eval in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (2.2.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (3.2.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (2.5.0)
# Requirement already satisfied: bleach in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (6.0.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (0.7.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (4.12.2)
# Requirement already satisfied: packaging in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (23.1)
# Requirement already satisfied: tinycss2 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (1.2.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (0.2.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (2.0.5)
# Requirement already satisfied: defusedxml in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (0.7.1)
# Requirement already satisfied: fastjsonschema in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (4.17.3)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (21.2.0)
# Requirement already satisfied: psutil in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from ipykernel->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (5.9.5)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from ipykernel->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (1.6.7)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (0.19.3)
# Requirement already satisfied: websocket-client in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (1.5.1)
# Requirement already satisfied: jupyter-events>=0.4.0 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (0.6.3)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (3.6.2)
# Requirement already satisfied: jupyter-server-terminals in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (0.4.4)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (2.21)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (0.1.1)
# Requirement already satisfied: uri-template in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (1.2.0)
# Requirement already satisfied: fqdn in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (1.5.1)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (2.0)
# Requirement already satisfied: isoduration in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (20.11.0)
# Requirement already satisfied: webcolors>=1.11 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/miniconda3-aq-v1/lib/python3.10/site-packages (from isoduration->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7->mols2grid) (1.2.3)
# Installing collected packages: jupyterlab-widgets, attrs, widgetsnbextension, ipywidgets, mols2grid
# Successfully installed attrs-21.4.0 ipywidgets-7.8.5 jupyterlab-widgets-1.1.11 mols2grid-2.0.0 widgetsnbextension-3.6.10
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Next, if you didn't already do it, create a directory where we want to store our generated data.
#
# Write python function `create_and_check_folder` to check if folder you want exist. If not - code need to create it.

# %%
import numpy as np
import pandas as pd
from chembl_webresource_client.new_client import new_client
from tqdm.auto import tqdm
import os

# %%
def create_and_check_folder(datapath):
    if os.path.exists(datapath):
        return True
    else:
        return False

# %%
create_and_check_folder(datapath="/home/praktikum/storage/meinschad_lukas_ff_pr")
# Out:
# True

# %% [markdown]
# Next, let's create resource objects for API access.
# What is an API? Check https://en.wikipedia.org/wiki/API
#
# More info and examples what you can get via ChEMBL API:
# - https://github.com/chembl/chembl_webresource_client
# - https://github.com/chembl/notebooks/blob/main/ChEMBL_webresource_client_examples.ipynb
# - https://chembl.blogspot.com/2015/07/chembl-python-client-update.html

# %%
# Create client instances for different resource types
targets_api = new_client.target
compounds_api = new_client.molecule
bioactivities_api = new_client.activity

# %%
type(targets_api)
# Out:
# chembl_webresource_client.query_set.QuerySet

# %% [markdown]
# The `chembl_webresource_client.query_set.QuerySet` is a custom Python class provided by the ChEMBL web resource client. Its main purpose is to serve as a flexible querying interface to the ChEMBL REST API. That;s kind of a specialized container that encapsulates the logic for:
# - Querying: It builds and manages API queries toward various endpoints (e.g., targets, molecules, assays, etc.).
# - Filtering & Searching: It supports methods such as .search(), .filter(), and more, enabling you to narrow down results based on your query parameters.
# - Lazy Evaluation and Pagination: Much like the QuerySet in Django’s ORM, it delays the actual API request until you iterate over or explicitly evaluate it. This approach optimizes performance and manages pagination automatically.
#
# You essentially interact with it as if it were a dataset from which you can retrieve specific biological data from the ChEMBL repository.

# %% [markdown]
# Let's get data about out target (protein of interest).

# %% [markdown]
# We need Uniprot ID or ChEMBL ID to get information about our target of interest from ChEMBL DB.
#
# In our case target of interest will be human EGFR kinase.

# %%
uniprot_id = "P27487"

# %% [markdown]
# Now let's fetch the target data from ChEMBL
# ... if you couldn't get an uniprot id easily, you could apply the API's filter function here and search by protein name ('pref_name__iexact') like:
#
# `targets = targets_api.filter(pref_name__iexact='Neuraminidase').only(**keep_data_dict)`
#
# For more info and examples check: https://github.com/chembl/notebooks/blob/main/ChEMBL_webresource_client_examples.ipynb.

# %%
# Get targets by uniprot id from ChEMBL but restrict it to specified values only: "target_chembl_id", "organism", "pref_name", "target_type"
targets_query = targets_api.get(target_components__accession=uniprot_id).only(
    "target_chembl_id", "organism", "pref_name", "target_type"
)

print(f'The type of the targets is "{type(targets_query)}"')
targets_query
# Out:
# The type of the targets is "<class 'chembl_webresource_client.query_set.QuerySet'>"
# [{'organism': 'Homo sapiens', 'pref_name': 'Dipeptidyl peptidase IV', 'target_chembl_id': 'CHEMBL284', 'target_type': 'SINGLE PROTEIN'}, {'organism': 'Homo sapiens', 'pref_name': 'Dipeptidyl peptidase II and dipeptidyl peptidase IV (DPP2 and DPP4)', 'target_chembl_id': 'CHEMBL2111469', 'target_type': 'SELECTIVITY GROUP'}]

# %% [markdown]
# The results of the query are stored in targets, a `QuerySet`, i.e. results of a `QuerySet` aren’t fetched from the database until you “ask” for them. Internally, a `QuerySet` can be constructed, filtered, sliced, and generally passed around without actually hitting the database. That's like a database "footprint" that we can play around with before making "real" request.
#
# The client implements a Django QuerySet-like interface with lazy evaluation, which means it will only evaluate a request for data when a value is required. This approach reduces number of network requests and increases performance. The API also caches results locally for faster retrieval.

# %% [markdown]
# To get "real" target data, we need to download it from ChEMBL (we need to "ask" DB for it).

# %%
targets = pd.DataFrame.from_records(targets_query)
targets
# Out:
#        organism                                          pref_name
# 0  Homo sapiens                            Dipeptidyl peptidase IV  \
# 1  Homo sapiens                            Dipeptidyl peptidase IV
# 2  Homo sapiens  Dipeptidyl peptidase II and dipeptidyl peptida...
#
#   target_chembl_id        target_type
# 0        CHEMBL284     SINGLE PROTEIN
# 1        CHEMBL284     SINGLE PROTEIN
# 2    CHEMBL2111469  SELECTIVITY GROUP

# %% [markdown]
# After checking the entries, select your target of interest (target ChEMBL ID).

# %%
### TODO: Select first entry and save it to a new variable
target = targets.iloc[0]
print(target)
# Out:
# organism                       Homo sapiens
# pref_name           Dipeptidyl peptidase IV
# target_chembl_id                  CHEMBL284
# target_type                  SINGLE PROTEIN
# Name: 0, dtype: object

# %% [markdown]
# Great! You found your target. Now you should save it's chembl id in `chembl_id` variable:

# %%
chembl_id = target["target_chembl_id"]
print(f"The target ChEMBL ID is {chembl_id}")
# Out:
# The target ChEMBL ID is CHEMBL284

# %% [markdown]
# ### Get bioactivity data

# %% [markdown]
# Now, we want to fetch the bioactivity data for the target of interest.
#
# In this step, we fetch the bioactivity data and filter it to only consider
# - human proteins,
# - bioactivity type IC50,
# - exact measurements (relation '='),
# - binding data (assay type 'B').
#
# If you want to use multiple target IDs, try 'target_chembl_id__in' and provide a list of the ids.
#
# For more info and examples check: https://github.com/chembl/notebooks/blob/main/ChEMBL_API_example_for_webinar.ipynb.

# %%
# Filter bioactivities by target, activity type, relation, assay_type
bioactivities_filtered = bioactivities_api.filter(
    target_chembl_id=chembl_id, ### add other filters here ###
).only(
    "activity_id",
    "assay_chembl_id",
    "assay_description",
    "assay_type",
    "molecule_chembl_id",
    "type",
    "standard_units",
    "relation",
    "standard_value",
    "target_chembl_id",
    "target_organism",
)

print(f"Length and type of bioactivities object: {len(bioactivities_filtered)}, {type(bioactivities_filtered)}")
# Out:
# Length and type of bioactivities object: 7291, <class 'chembl_webresource_client.query_set.QuerySet'>

# %% [markdown]
# In our bioactivity set, each entry holds important information.
#
# Try to find out the molecule_chembl_id of your first entry of the set. What else is stored in the first entry?
#
# NB: You can check info without downloading entire dataset (it can be very time-consuming).

# %%
# code to find out the molecule_chembl_id of your first entry of the set and check out what is also stored there
molecule_chemblid_fe = bioactivities_filtered[0]["molecule_chembl_id"]
print(f"First Entry Chembl ID= {molecule_chemblid_fe}")
# Out:
# First Entry Chembl ID= CHEMBL93558

# %% [markdown]
# Now, let's download the bioactivity data from ChEMBL, similar as you did it for your target, and save in pandas dataframe `bioactivities_df`.

# %%
bioactivities_df = bioactivities_api.filter(
    target_chembl_id=molecule_chemblid_fe, ### add other filters here ###
).only(
    "activity_id",
    "assay_chembl_id",
    "assay_description",
    "assay_type",
    "molecule_chembl_id",
    "type",
    "standard_units",
    "relation",
    "standard_value",
    "target_chembl_id",
    "target_organism",
)
bioactivities_df
# Out:
# []

# %% [markdown]
# Check how bioactivity data looks like? Which columns has dataset? How many rows in it? Shape of the df?

# %%
print(bioactivity_fe)
# Out:
# []

# %% [markdown]
# Note that the first two rows describe the same bioactivity entry; we will remove such artifacts later during the deduplication step.
#
# Note also that we have columns for `standard_units/units` and `standard_values/values`; in the following, we will use the standardized columns (standardization by ChEMBL), and thus, we drop the other two columns.

# %% [markdown]
# So now drop the `units` and `value` column.

# %%
## TODO: drop the "units" and "value" columns

# %% [markdown]
# Now let's filter and preprocess our bioactivity data.
#
# You need to do the following:
#
# 1. Convert `standard_value`’s datatype from `object` to `float` (in order to make these values usable in calculations later on)
# 2. Delete entries with missing values (because we can't use missed values in calculations)
# 3. Keep only entries with `standard_unit == nM` (because we only want to keep bioactivity entries in nM)
# 4. Find duplicate molecules (because sometimes the same molecule (`molecule_chembl_id`) has been tested more than once) and calculate the geometric mean of IC50 for them --> store as a single entry with this averaged IC50 value
# 5. Reset `DataFrame` index (since we deleted some rows and now want the index to be continuous)
# 6. Rename columns (from "standard_value" to "IC50", from "standard_units" to "units")

# %%
## TODO: Follow the list above and clean up bioactivities_df :)

# %%
print(f"Congratulations! Now you have a set of {len(bioactivities_df)} molecule ids with respective IC50 values for our target protein.")

# %% [markdown]
# ### Get compound data
#
# We have now a proper df containing all molecules that were tested against our target - EGFR in this case - with measured bioactivity data.
# Now let's get the molecular structures of the molecules that are linked to the respective bioactivity ChEMBL IDs.

# %% [markdown]
# Let’s have a look at the compounds from ChEMBL which we have defined bioactivity data for: let's fetch compound ChEMBL IDs and related to them structures.

# %%
compounds_provider = compounds_api.filter(
    molecule_chembl_id__in=list(bioactivities_df["molecule_chembl_id"])
).only("molecule_chembl_id", "molecule_structures")

# %% [markdown]
# and now let's download them ...

# %% [markdown]
# Again, we want to export the `QuerySet` object into a `pandas.DataFrame`.
# Given the data volume, **this can take some time**, so feel free to go for a coffee.
#
# For that reason, we will first obtain the list of records through tqdm, so we get a nice progress bar and some ETAs. ETAs stands for Estimated Time of Arrival. It is used to indicate the estimated time remaining for the operation to complete (how long until your task is complete).

# %%
compounds = list(tqdm(compounds_provider))

# %% [markdown]
# Let's pass the list of compounds to the DataFrame `compounds_df`.

# %%
compounds_df = ### code ###

# %% [markdown]
# Wow, you did it! But before looking at the structures of molecules, let's preprocess and filter received data:
#
# 1) Remove rows with missing molecule structure entry
# 2) Delete duplications (by `molecule_chembl_id`)
# 3) Get for each molecule only canonical SMILES from entire `molecule_structures` column and save in new `smiles` column

# %%
### code for that

# %% [markdown]
# So far, we have multiple different molecular structure representations as a dict in "molecule_structures" column. Remove redundunt data to keep only the canonical SMILES.
#
# Hint: "molecule_structures" as dict --> "molecule_structures" as string.
#
# Hint: first check which key in dict (dict = data structure that consist of `{ key: value }` pairs) is responsible for storing canonical SMILES representation

# %%
## TODO: What's inside the magic 'molecule_structures' box? We only want to keep the canonical SMILES!

# %% [markdown]
# Sanity check: Remove all molecules without a canonical SMILES string.

# %%
### code for that

# %% [markdown]
# ### Merge both datasets
#
# Merge values of interest from `bioactivities_df` and `compounds_df` in an `output_df` based on the compounds’ ChEMBL IDs (`molecule_chembl_id`), keeping the following columns:
#
# - ChEMBL IDs: molecule_chembl_id
# - SMILES: smiles
# - units: units
# - IC50: IC50

# %%
## TODO: Merge the two dataframes. What is in the final DataFrame?

# %% [markdown]
# ### Add pIC50 values
#
# Before the practical part, you have read the literature and answered the questions. therefore, you will be able to complete the next task without difficulty.
#
# Your next tasks is:
# - convert the IC50 values to pIC50 in a separate column `pIC50`

# %%
## TODO: create a function convert_ic50_to_pic50 which operates the calculation!

# %%
## TODO: Use your function to add a pIC50 column to your DataFrame

# %% [markdown]
# **Question to answer**:
# - What is the difference in using IC₅₀ and pIC₅₀ for interpreting ingibitor potency?
# - Which units are applicable for each of them?
# - How can you evaluate high/low IC₅₀ and high/low pIC₅₀ value? Why?
# - Which values are more appropriate to use for QSAR models and comparisons? Why?

# %% [markdown]
# ## Visualisazion
#
# Let’s have a look at the distribution of our collected data set's potency as ingibitor. To evaluate results easily we need proper visualization technic for it.
#
# Which value it would be better to use for plotting (histogram)? Why?

# %% [markdown]
# Hint: you can use for plotting even built-in methods from `pandas` lib. You can learn more about it from:
# - https://mode.com/example-gallery/python_histogram
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.hist.html.

# %%
##TODO: Visualize potency distribution

# %% [markdown]
# **Question**: Which conclusions you can make based on this plot?

# %% [markdown]
# In the next steps, let's add a column for RDKit molecule objects to our `DataFrame` and look at the structures of the molecules with the highest potency values.

# %%
## TODO: Add molecule column 'Mol', PandasTools is your friend but not the only possible solution (check rdkit.Chem documentation)

# %%
## TODO: Sort molecules by potency, clean up the DataFrame

# %%
## TODO: illustrate the 5 most active compounds
## TODO: illustrate the 5 least active compounds

# %% [markdown]
# ### Write output data to file
#
# You'll need received bioactivity-compound dataset in the following tasks, thus you need to save the data as `csv` file.
#
# **Note** that it is advisable to drop the 'Mol' column (which only contains an image of the molecules) when saving the data.

# %%
## TODO: drop column with visualized molecule

# %%
## TODO: Save your data to a csv file

# %% [markdown]
# **Result of your today's work PART 1**: you've collected bioactivity data for the target of interest from the ChEMBL database, filtered the data set in order to only contain molecules with measured IC50 bioactivity values, visualised molecules, etc.

# %% [markdown]
# Let's go to the next steps ...
